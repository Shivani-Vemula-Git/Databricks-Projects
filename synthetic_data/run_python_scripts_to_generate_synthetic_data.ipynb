# %%
# %pip install Faker

# %%
dbutils.library.restartPython()

# %%
# %sh python /Workspace/Users/vemulashivaniwebsite@gmail.com/Databricks-Projects/synthetic_data/gen_data.py

# %%
# %sh python /Workspace/Users/vemulashivaniwebsite@gmail.com/Databricks-Projects/synthetic_data/historical_orders.py

# %%
# %sh python /Workspace/Users/vemulashivaniwebsite@gmail.com/Databricks-Projects/synthetic_data/reviews_data.py
